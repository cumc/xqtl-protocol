# %%
sample = readr::read_delim("~/Project/PCA_test/MWE_AD/MWE_pheno.txt","\t")
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   ID = col_character(),
#   NYGC_VCF_ID = col_character(),
#   ProjectID = col_character(),
#   Columbia_Description = col_character(),
#   SEX = col_character(),
#   AD = col_double(),
#   AGE = col_double(),
#   APOE = col_double(),
#   RACE = col_double(),
#   STUDY = col_character(),
#   FID = col_character(),
#   IID = col_character()
# )

# %%
length(unique(sample$IID))
# Out:
# [1] 50

# %%
a = readRDS("~/Project/PCA_test/MWE_AD/MWE_pheno...pca.projected.rds")
b = readRDS("~/Project/PCA_test/MWE_AD/MWE_pheno...pca.projected.mahalanobis.rds")
c = readRDS("~/Project/PCA_test/MWE_AD/MWE_pheno...pca..rds")

# %%
pca_output = a$pc_scores

# %%
mtx = pca_output%>%select(contains("PC"))
mtx = t(mtx)
colnames(mtx) <- pca_output$IID
rownames(mtx)
mtx = mtx%>%as_tibble()%>%mutate("#id" = rownames(mtx))%>%select("#id",everything())
mtx
# Out:
#  [1] "PC1"  "PC2"  "PC3"  "PC4"  "PC5"  "PC6"  "PC7"  "PC8"  "PC9"  "PC10"
#    #id  03AD5306     04AD6279      04AD7497    05AD8132      07AD2616
# 1  PC1  -0.150675145 -0.1654903086 -0.15162428 -0.1528885686 -0.13975358
# 2  PC2   0.040068703  0.0860645798  0.05781165  0.0467193134  0.07134565
# 3  PC3  -0.024189775 -0.0223923623 -0.04491636 -0.0668002681 -0.04921414
# 4  PC4  -0.029701270  0.0075526539 -0.01004420 -0.0006437757 -0.02702515
# 5  PC5  -0.032074941 -0.0137438971 -0.02001985 -0.0534291338 -0.03554630
# 6  PC6  -0.081256317 -0.0528485426 -0.06430855 -0.0816862020 -0.04688550
# 7  PC7   0.045456506 -0.0300779853 -0.06462846 -0.0045355069 -0.01536557
# 8  PC8   0.031318718 -0.0093846318  0.01648811  0.0532783142  0.01183579
# 9  PC9   0.005556461  0.0001347629  0.11380550 -0.1103739866  0.05321964
# 10 PC10 -0.083654284 -0.0121283908  0.03112804  0.0564445646 -0.03376234
#    07AD4869    09AD13237    09AD16296   10AD31612   ... 06AD9186
# ...

# %%
length(a$pc_scores$ID.y)
# Out:
# [1] 19

# %%
length(a$pc_scores$IID)
# Out:
# [1] 19

# %%
library("tidyverse")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
test = tibble('#Study' = c(1,2), molecular_pheno = "./MWE_pheno.txt", genotype_list = "MWE_geno.txt", covariate = "MWE_pheno...1_2_3.pca.rds" )

# %%
test%>%write_delim("~/test_recipe")

# %%
test
# Out:
#   #Study molecular_pheno genotype_list covariate
# 1 1      ./MWE_pheno.txt MWE_geno.txt  MWE_pheno...1_2_3.pca.rds
# 2 2      ./MWE_pheno.txt MWE_geno.txt  MWE_pheno...1_2_3.pca.rds
